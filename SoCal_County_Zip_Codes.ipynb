# %%
# Import dependencies for CA county & zip code csv file
import pandas as pd

# %%
# zip code csv file path & read
file = 'SoCal_County_ZIP_Codes.csv'

# Read csv
socal_cnty_zip = pd.read_csv('SoCal_County_ZIP_Codes.csv')
socal_cnty_zip.head()
# Out:
#    Zip Code         City       County
# 0     90001  Los Angeles  Los Angeles
# 1     90002  Los Angeles  Los Angeles
# 2     90003  Los Angeles  Los Angeles
# 3     90004  Los Angeles  Los Angeles
# 4     90005  Los Angeles  Los Angeles

# %%
# size of rows & cols
socal_cnty_zip.shape
# Out:
# (1295, 3)

# %%
# column names
socal_cnty_zip.columns
# Out:
# Index(['Zip Code', 'City', 'County'], dtype='object')

# %%
socal_cnty_zip
# Out:
#       Zip Code          City          County
# 0        90001   Los Angeles     Los Angeles
# 1        90002   Los Angeles     Los Angeles
# 2        90003   Los Angeles     Los Angeles
# 3        90004   Los Angeles     Los Angeles
# 4        90005   Los Angeles     Los Angeles
# 5        90006   Los Angeles     Los Angeles
# 6        90007   Los Angeles     Los Angeles
# 7        90008   Los Angeles     Los Angeles
# 8        90009   Los Angeles     Los Angeles
# 9        90010   Los Angeles     Los Angeles
# 10       90011   Los Angeles     Los Angeles
# 11       90012   Los Angeles     Los Angeles
# 12       90013   Los Angeles     Los Angeles
# 13       90014   Los Angeles     Los Angeles
# 14       90015   Los Angeles     Los Angeles
# 15       90016   Los Angeles     Los Angeles
# 16       90017   Los Angeles     Los Angeles
# 17       90018   Los Angeles     Los Angeles
# 18       90019   Los Angeles     Los Angeles
# 19       90020   Los Angeles     Los Angeles
# ...

# %%
socal_cnty_zip.shape
# Out:
# (1295, 3)

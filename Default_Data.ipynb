# %%
import pandas as pd
import os
import csv

# %%
file = "hmeq.csv"
install_file = pd.read_csv(file)
install_file.head()
# Out:
#    BAD  LOAN  MORTDUE     VALUE   REASON     JOB   YOJ  DEROG  DELINQ  \
# 0    1  1100  25860.0   39025.0  HomeImp   Other  10.5    0.0     0.0
# 1    1  1300  70053.0   68400.0  HomeImp   Other   7.0    0.0     2.0
# 2    1  1500  13500.0   16700.0  HomeImp   Other   4.0    0.0     0.0
# 3    1  1500      NaN       NaN      NaN     NaN   NaN    NaN     NaN
# 4    0  1700  97800.0  112000.0  HomeImp  Office   3.0    0.0     0.0
#
#         CLAGE  NINQ  CLNO  DEBTINC
# 0   94.366667   1.0   9.0      NaN
# 1  121.833333   0.0  14.0      NaN
# 2  149.466667   1.0  10.0      NaN
# 3         NaN   NaN   NaN      NaN
# 4   93.333333   0.0  14.0      NaN

# %%
install_file_sort = install_file.sort_values("VALUE",ascending = True)
install_file_sort = install_file_sort.rename(columns = {"LOAN": "Loan Total","MORTDUE":"Mortgage Due","VALUE": "Value",
                                                        "REASON":"Reason of Default","JOB":"Occupation",
                                                       "YOJ":"Years at Job","DEROG":"Major derogatory",
                                                       "DELINQ":"Delinquent credit lines",
                                                       "CLAGE":"Age Of Oldest Credit Line in Months",
                                                       "NINQ":"Number Of Recent Credit Inquiries", "CLNO":"Number of Credit Lines"
                                                       ,"DEBTINC":"Debt-to-Income Ratio"})
install_file_clean = install_file_sort.dropna(subset = ["Value"])
install_file_clean
# Out:
#       BAD  Loan Total  Mortgage Due     Value Reason of Default Occupation  \
# 3538    0       18600       57300.0    8000.0           DebtCon      Other
# 40      1        3000           NaN    8800.0           HomeImp      Other
# 156     1        5000           NaN    9100.0           HomeImp      Other
# 213     1        5200           NaN    9500.0           DebtCon      Other
# 940     1        9100           NaN   11550.0           HomeImp      Other
# 616     1        7800           NaN   11702.0           HomeImp      Other
# 3683    0       19400       63508.0   12414.0           DebtCon      Other
# 4225    1       22000       82000.0   12500.0           DebtCon    ProfExe
# 3757    0       20000       59936.0   12737.0           DebtCon      Other
# 254     1        5500           NaN   12972.0           HomeImp      Other
# 248     1        5500           NaN   13770.0           HomeImp        Mgr
# ...

# %%
# bins = [0,20000,40000,60000,80000,100000,200000,400000,600000,800000,1000000]
# group_names = ["<20000","20000-39999","40000-59999","60000-79999","80000-99999","100000-199999","200000-399999","400000-599999","600000-799999","800000+"]

# install_file_clean["Value"] = pd.cut(install_file_clean["Value"],bins,labels=group_names,right=False)
# NewTable = install_file_clean.groupby("Value").count()
# NewTable

# %%
Clean_file = install_file_clean.to_csv("Clean File.csv")

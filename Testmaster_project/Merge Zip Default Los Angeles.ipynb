# %%
import matplotlib
import matplotlib.pyplot as plt
import csv
import pandas as pd
import os
import numpy as np

# %%
File1 = "../Clean Default.csv"
Default_info = pd.read_csv(File1)
Default_info.head()
# Out:
#    Unnamed: 0  BAD  Loan Total  Mortgage Due  Home Value Reason of Default  \
# 0        3538    0       18600       57300.0      8000.0           DebtCon
# 1          40    1        3000           NaN      8800.0           HomeImp
# 2         156    1        5000           NaN      9100.0           HomeImp
# 3         213    1        5200           NaN      9500.0           DebtCon
# 4         940    1        9100           NaN     11550.0           HomeImp
#
#   Occupation  Years at Job  Major derogatory  Delinquent credit lines  \
# 0      Other           6.0               NaN                      NaN
# 1      Other           2.0               0.0                      1.0
# 2      Other           1.0               0.0                      0.0
# 3      Other           1.0               0.0                      1.0
# 4      Other           NaN               0.0                      0.0
#
#    Age Of Oldest Credit Line in Months  Number Of Recent Credit Inquiries  \
# 0                            68.000000                                1.0
# 1                            77.766667                                0.0
# 2                            54.733333                                2.0
# 3                            81.100000                                1.0
# 4                            51.933333                                1.0
#
#    Number of Credit Lines  Debt-to-Income Ratio
# 0                    17.0                   NaN
# 1                     3.0                   NaN
# 2                     8.0                   NaN
# 3                     2.0                   NaN
# 4                     3.0                   NaN

# %%
newDefault = Default_info.drop(Default_info.iloc[:, 5:],axis = 1)

# %%
File2 = "Clean Los Angeles.csv"
LA_info = pd.read_csv(File2)
LA_info = LA_info.drop(columns = ["Unnamed: 0","Unnamed: 0.1","Zipcode","Type"],axis = 1)
LA_info = LA_info.convert_objects(convert_numeric=True)
LA_info['Los Angeles Zip Codes'] = LA_info['Los Angeles Zip Codes'].astype(np.float64)
LA_info = LA_info.sort_values("Home Value",ascending = True)
LA_info
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   after removing the cwd from sys.path.
#     Los Angeles Zip Codes  Home Value
# 1                 90002.0    378400.0
# 0                 90001.0    381400.0
# 49                90059.0    392300.0
# 2                 90003.0    402600.0
# 9                 90011.0    415000.0
# 50                90061.0    418500.0
# 20                90023.0    428300.0
# 40                90044.0    434900.0
# 19                90022.0    454600.0
# 36                90040.0    459000.0
# 65                90744.0    464200.0
# 33                90037.0    477800.0
# 52                90063.0    483200.0
# 76                91331.0    484600.0
# 29                90033.0    489400.0
# 87                91402.0    492300.0
# 48                90057.0    496100.0
# 43                90047.0    497600.0
# 68                91303.0    516600.0
# 78                91342.0    523700.0
# 81                91345.0    540600.0
# 77                91335.0    547200.0
# 82                91352.0    548100.0
# 70                91306.0    565800.0
# 51                90062.0    572800.0
# 10                90012.0    574300.0
# 97                91605.0    580000.0
# 18                90020.0    581400.0
# 89                91405.0    582000.0
# 79                91343.0    594400.0
# ..                    ...         ...
# 22                90025.0    968900.0
# 83                91356.0    982000.0
# 59                90094.0   1010300.0
# 34                90038.0   1024400.0
# 35                90039.0   1046000.0
# 88                91403.0   1085300.0
# 92                91423.0   1114200.0
# 17                90019.0   1121700.0
# 56                90067.0   1178900.0
# 41                90045.0   1201000.0
# 21                90024.0   1252400.0
# 30                90034.0   1264800.0
# 47                90056.0   1335200.0
# 96                91604.0   1363500.0
# 3                 90004.0   1379700.0
# 55                90066.0   1430600.0
# 57                90068.0   1444000.0
# 24                90027.0   1485600.0
# 31                90035.0   1512600.0
# 42                90046.0   1516600.0
# 53                90064.0   1602500.0
# 93                91436.0   1652600.0
# 32                90036.0   1739100.0
# 44                90048.0   1891800.0
# 61                90291.0   2056100.0
# 58                90077.0   2565700.0
# 45                90049.0   2646900.0
# 60                90272.0   3037000.0
# 8                 90010.0         NaN
# 46                90051.0         NaN
#
# [100 rows x 2 columns]

# %%
#Convert the column Home Value from the LB Dataframe to list
list1 = [10000,25000,50000,75000,100000,125000,150000] #change these numbers and replace it with the average income per zip code. That way we're able to go get different charts. 

#Create empty list to store values
Total_list= [];
Default_list = [];
Not_Default_list = []

#Run a for loop to see all Default table that are less than the current House value i  
for i in list1:
    Tabless = Default_info[Default_info["Home Value"] < i]
    Total = Tabless['BAD'].count()
    Total_list.append(Total)
    Default = (Tabless['BAD'] == 1).sum()
    Default_list.append(Default)
    Not_Default = (Tabless['BAD'] == 0).sum()
    Not_Default_list.append(Not_Default)
     

#Making a DataFrame from the list we were able to obtain 
Numbers = pd.Series(list1)
df = pd.DataFrame({"Total Count of Default & Not Default": Total_list, "Sum of Default": Default_list,"Sum of Not Default":Not_Default_list})
df = df.set_index(Numbers)
df = df.drop_duplicates('Sum of Default')
df.head(10)
# Out:
#         Total Count of Default & Not Default  Sum of Default  \
# 10000                                      4               3
# 25000                                     47              29
# 50000                                    624             196
# 75000                                   2056             453
# 100000                                  3533             705
# 125000                                  4526             843
# 150000                                  4964             936
#
#         Sum of Not Default
# 10000                    1
# 25000                   18
# 50000                  428
# 75000                 1603
# 100000                2828
# 125000                3683
# 150000                4028

# %%
percent_default =(df["Sum of Default"]/df["Total Count of Default & Not Default"]*100).tolist()
percent_not_default = (df["Sum of Not Default"]/df["Total Count of Default & Not Default"]*100).tolist()

ind = np.arange(len(percent_default))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(ind - width/2, percent_default, width,label= "Default")
rects2 = ax.bar(ind + width/2, percent_not_default, width, label= "Paid")

ax.set_ylabel('Percentage')
ax.set_title('Percentage vs Home Value')
ax.set_xticks(ind)
ax.set_xticklabels(('$10k','$25k','$50k','$75k','$100k','$125k','$150k'))
ax.legend()

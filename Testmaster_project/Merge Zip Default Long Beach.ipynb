# %%
import matplotlib
import matplotlib.pyplot as plt
import csv
import pandas as pd
import os
import numpy as np

# %%
Default = "../Clean Default.csv"
Default_info = pd.read_csv(Default)
Default_info
# Out:
#       Unnamed: 0  BAD  Loan Total  Mortgage Due  Home Value Reason of Default  \
# 0           3538    0       18600       57300.0      8000.0           DebtCon
# 1             40    1        3000           NaN      8800.0           HomeImp
# 2            156    1        5000           NaN      9100.0           HomeImp
# 3            213    1        5200           NaN      9500.0           DebtCon
# 4            940    1        9100           NaN     11550.0           HomeImp
# 5            616    1        7800           NaN     11702.0           HomeImp
# 6           3683    0       19400       63508.0     12414.0           DebtCon
# 7           4225    1       22000       82000.0     12500.0           DebtCon
# 8           3757    0       20000       59936.0     12737.0           DebtCon
# 9            254    1        5500           NaN     12972.0           HomeImp
# 10           248    1        5500           NaN     13770.0           HomeImp
# 11          3707    0       19500       58638.0     13930.0           DebtCon
# 12          3655    0       19200       65206.0     13933.0           DebtCon
# 13            45    1        3000           NaN     14100.0           HomeImp
# 14            44    1        3000           NaN     14500.0           HomeImp
# 15          4155    0       21700       60792.0     14580.0           DebtCon
# 16          3739    0       19800       63701.0     14609.0           DebtCon
# 17            90    1        4000        7000.0     16020.0           HomeImp
# 18          1429    1       10900           NaN     16365.0           HomeImp
# 19             2    1        1500       13500.0     16700.0           HomeImp
# 20            24    1        2400           NaN     17180.0           HomeImp
# 21            88    1        4000        5700.0     18000.0           DebtCon
# 22           869    1        8800        2800.0     18361.0           HomeImp
# 23          1320    1       10500           NaN     18600.0           HomeImp
# 24          2546    1       15000       18500.0     19000.0           DebtCon
# 25            99    1        4100           NaN     19132.0           HomeImp
# 26            27    1        2500       15000.0     20200.0           HomeImp
# 27            39    1        3000        7000.0     20300.0           HomeImp
# 28            62    1        3500       19400.0     20494.0           HomeImp
# 29           437    1        6700           NaN     20631.0           HomeImp
# ...          ...  ...         ...           ...         ...               ...
# 5818        5382    0       30900      190480.0    298239.0           DebtCon
# 5819        5483    0       33200      195971.0    298682.0           DebtCon
# 5820        5747    1       43300      217840.0    299171.0           DebtCon
# 5821        5424    0       31800      195134.0    299299.0           DebtCon
# 5822        5450    0       32300      194350.0    299720.0           DebtCon
# 5823        5876    1       53600      235895.0    299772.0           HomeImp
# 5824        5810    1       50000      220528.0    300900.0           HomeImp
# 5825        5380    0       30900      189798.0    301984.0           DebtCon
# 5826        5874    1       53400      228236.0    305514.0           HomeImp
# 5827        3812    1       20000       21300.0    308600.0           HomeImp
# 5828        5542    1       35000      227000.0    316000.0           HomeImp
# 5829        5567    1       36100      233417.0    324987.0           HomeImp
# 5830        5615    1       38000      290000.0    364000.0           DebtCon
# 5831        5666    1       40000      331000.0    415000.0           DebtCon
# 5832        5659    0       40000      362000.0    465000.0           HomeImp
# 5833        5677    0       40600      362909.0    466731.0           HomeImp
# 5834        5742    0       43200      367917.0    466755.0           HomeImp
# 5835        5670    0       40300      369874.0    467112.0           HomeImp
# 5836        5682    0       40700      371003.0    467818.0           HomeImp
# 5837        5702    0       41600      365528.0    469694.0           HomeImp
# 5838        5710    0       41800      363737.0    469748.0           HomeImp
# 5839        5721    0       42300      367089.0    469771.0           HomeImp
# 5840        5697    0       41400      362578.0    471827.0           HomeImp
# 5841        5545    1       35000      391000.0    505000.0           DebtCon
# 5842        5638    1       39000      399412.0    511164.0           DebtCon
# 5843        5586    1       36600      397299.0    512650.0           DebtCon
# 5844        5665    1       40000           NaN    850000.0           HomeImp
# 5845        5706    1       41700           NaN    854112.0           HomeImp
# 5846        5707    1       41700           NaN    854114.0           HomeImp
# 5847        5752    1       43500           NaN    855909.0           HomeImp
#
#      Occupation  Years at Job  Major derogatory  Delinquent credit lines  \
# 0         Other           6.0               NaN                      NaN
# 1         Other           2.0               0.0                      1.0
# 2         Other           1.0               0.0                      0.0
# 3         Other           1.0               0.0                      1.0
# 4         Other           NaN               0.0                      0.0
# 5         Other           0.0               0.0                      0.0
# 6         Other           5.0               NaN                      NaN
# 7       ProfExe           3.0               0.0                      0.0
# 8         Other           5.0               NaN                      NaN
# 9         Other           1.0               0.0                      1.0
# 10          Mgr           5.0               0.0                      1.0
# 11        Other           4.0               NaN                      NaN
# 12        Other           7.0               NaN                      NaN
# 13        Other           1.0               0.0                      0.0
# 14        Other           3.0               0.0                      0.0
# 15        Other           5.0               NaN                      NaN
# 16        Other           4.0               NaN                      NaN
# 17        Other          18.0               0.0                      1.0
# 18        Other           NaN               0.0                      0.0
# 19        Other           4.0               0.0                      0.0
# 20        Other           NaN               0.0                      0.0
# 21        Other           NaN               0.0                      0.0
# 22        Other           2.0               3.0                      1.0
# 23        Other          24.0               NaN                      NaN
# 24        Other           2.0               0.0                      1.0
# 25        Other           0.0               0.0                      0.0
# 26          NaN          18.0               0.0                      0.0
# 27        Other           3.0               0.0                      0.0
# 28        Other           5.0               0.0                      0.0
# 29          Mgr           4.0               0.0                      0.0
# ...         ...           ...               ...                      ...
# 5818      Other          27.0               0.0                      1.0
# 5819      Other          29.0               0.0                      0.0
# 5820    ProfExe          31.0               0.0                      0.0
# 5821      Other          29.0               0.0                      0.0
# 5822      Other          28.0               0.0                      0.0
# 5823        Mgr           5.0               0.0                      0.0
# 5824       Self           5.0               0.0                      0.0
# 5825      Other          28.0               0.0                      0.0
# 5826       Self           6.0               0.0                      0.0
# 5827    ProfExe           2.0               1.0                      0.0
# 5828    ProfExe           3.0               0.0                      0.0
# 5829    ProfExe           4.0               0.0                      0.0
# 5830    ProfExe           0.3               0.0                      0.0
# 5831    ProfExe          22.0               0.0                      0.0
# 5832    ProfExe           3.0               0.0                      0.0
# 5833    ProfExe           4.0               0.0                      0.0
# 5834    ProfExe           3.0               0.0                      0.0
# 5835    ProfExe           2.0               0.0                      0.0
# 5836    ProfExe           1.0               0.0                      0.0
# 5837    ProfExe           3.0               0.0                      0.0
# 5838    ProfExe           4.0               0.0                      0.0
# 5839    ProfExe           3.0               0.0                      0.0
# 5840    ProfExe           1.0               0.0                      0.0
# 5841    ProfExe           4.5               0.0                      0.0
# 5842    ProfExe           5.0               0.0                      0.0
# 5843    ProfExe           4.0               0.0                      0.0
# 5844      Other          17.0               0.0                      0.0
# 5845      Other          16.0               0.0                      0.0
# 5846      Other          18.0               0.0                      0.0
# 5847      Other          16.0               0.0                      0.0
#
#       Age Of Oldest Credit Line in Months  Number Of Recent Credit Inquiries  \
# 0                               68.000000                                1.0
# 1                               77.766667                                0.0
# 2                               54.733333                                2.0
# 3                               81.100000                                1.0
# 4                               51.933333                                1.0
# 5                               44.629592                                2.0
# 6                               64.407605                                1.0
# 7                              117.766667                                6.0
# 8                               63.395400                                0.0
# 9                               82.294266                                0.0
# 10                             167.366667                                1.0
# 11                              69.005027                                0.0
# 12                              57.591831                                0.0
# 13                             104.200000                                0.0
# 14                               9.300000                               14.0
# 15                              62.856357                                1.0
# 16                              62.359738                                1.0
# 17                              85.800000                                2.0
# 18                              59.548703                                1.0
# 19                             149.466667                                1.0
# 20                              14.566667                                3.0
# 21                              12.200000                                0.0
# 22                             107.766667                                4.0
# 23                                    NaN                                NaN
# 24                              20.166667                                0.0
# 25                             100.774652                                0.0
# 26                             136.066667                                1.0
# 27                              50.800000                                5.0
# 28                              95.933333                                0.0
# 29                             174.721834                                1.0
# ...                                   ...                                ...
# 5818                           164.604871                                0.0
# 5819                           138.566648                                0.0
# 5820                           232.270068                                1.0
# 5821                           161.885126                                0.0
# 5822                           170.196867                                0.0
# 5823                           112.748282                                7.0
# 5824                             0.000000                                0.0
# 5825                           150.917363                                0.0
# 5826                            11.148069                                0.0
# 5827                           274.900000                                0.0
# 5828                           160.266667                                1.0
# 5829                           152.245428                                0.0
# 5830                           126.833333                                6.0
# 5831                           242.466667                                8.0
# 5832                           313.466667                                4.0
# 5833                           305.812419                                4.0
# 5834                           312.306339                                4.0
# 5835                           328.198894                                4.0
# 5836                           316.604442                                3.0
# 5837                           304.982884                                3.0
# 5838                           327.743755                                4.0
# 5839                           310.051524                                4.0
# 5840                           292.135985                                4.0
# 5841                           192.766667                                0.0
# 5842                           181.962401                                0.0
# 5843                           197.516684                                0.0
# 5844                           186.666667                                1.0
# 5845                           180.608878                                0.0
# 5846                           189.099378                                1.0
# 5847                           196.403636                                0.0
#
#       Number of Credit Lines  Debt-to-Income Ratio
# 0                       17.0                   NaN
# 1                        3.0                   NaN
# 2                        8.0                   NaN
# 3                        2.0                   NaN
# 4                        3.0                   NaN
# 5                        7.0             21.271785
# 6                       16.0             40.570169
# 7                       23.0                   NaN
# 8                       17.0             40.446579
# 9                        2.0             36.986744
# 10                       8.0                   NaN
# 11                      16.0             42.500025
# 12                      16.0             42.502435
# 13                      19.0                   NaN
# 14                       2.0                   NaN
# 15                      17.0             40.315819
# 16                      17.0             41.874198
# 17                      23.0                   NaN
# 18                       2.0             24.195904
# 19                      10.0                   NaN
# 20                       4.0                   NaN
# 21                      17.0                   NaN
# 22                       3.0                   NaN
# 23                       NaN                   NaN
# 24                       2.0                   NaN
# 25                      19.0             33.840920
# 26                      19.0                   NaN
# 27                       9.0                   NaN
# 28                       9.0                   NaN
# 29                       8.0             62.246451
# ...                      ...                   ...
# 5818                    23.0             39.601452
# 5819                    22.0             39.887562
# 5820                    24.0             43.114691
# 5821                    22.0             38.637024
# 5822                    23.0             40.251510
# 5823                    22.0             44.945929
# 5824                     2.0                   NaN
# 5825                    22.0             37.236508
# 5826                     2.0             34.558417
# 5827                    30.0                   NaN
# 5828                    25.0                   NaN
# 5829                    25.0             21.862939
# 5830                    32.0                   NaN
# 5831                    34.0                   NaN
# 5832                    15.0                   NaN
# 5833                    14.0             42.930339
# 5834                    15.0             42.623574
# 5835                    15.0             40.799921
# 5836                    14.0             41.723899
# 5837                    15.0             43.363624
# 5838                    14.0             43.809292
# 5839                    14.0             42.603641
# 5840                    15.0             40.772058
# 5841                    22.0                   NaN
# 5842                    21.0             43.730032
# 5843                    21.0             43.458327
# 5844                    24.0                   NaN
# 5845                    23.0             42.071645
# 5846                    23.0             43.258779
# 5847                    23.0             42.985408
#
# [5848 rows x 14 columns]

# %%
newDefault = Default_info.drop(Default_info.iloc[:, 5:],axis = 1)

# %%
File2 = "../Long Beach/Clean Long Beach.csv"
LB_info = pd.read_csv(File2)
LB_info = LB_info.drop(columns = ["Unnamed: 0","Unnamed: 0.1","Zipcode","Type"],axis = 1)
LB_info = LB_info.convert_objects(convert_numeric=True)
LB_info['Long Beach Zip Code'] = LB_info['Long Beach Zip Code'].astype(np.float64)
LB_info = LB_info.sort_values("Home Value",ascending = True)
LB_info
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   after removing the cwd from sys.path.
#     Long Beach Zip Code  Home Value
# 0               90802.0    378200.0
# 9               90813.0    396200.0
# 3               90805.0    466700.0
# 8               90810.0    477400.0
# 2               90804.0    491300.0
# 4               90806.0    535500.0
# 5               90807.0    639100.0
# 6               90808.0    685500.0
# 11              90815.0    697200.0
# 10              90814.0    750600.0
# 1               90803.0    985300.0
# 7               90809.0         NaN

# %%
#Convert the column Home Value from the LB Dataframe to list
Home_Value = [400000,600000,50000,75000,100000,125000,150000]

#Create empty list to store values
Total_list= [];
Default_list = [];
Not_Default_list = [];

#Run a for loop to see all Default table that are less than the current House value i  
for i in list1:
    Tabless = Default_info[Default_info["Home Value"] < i]
    Total = Tabless['BAD'].count()
    Total_list.append(Total)
    Default = (Tabless['BAD'] == 1).sum()
    Default_list.append(Default)
    Not_Default = (Tabless['BAD'] == 0).sum()
    Not_Default_list.append(Not_Default)
     

#Making a DataFrame from the list we were able to obtain 
Numbers = pd.Series(Home_Value)
df = pd.DataFrame({"Total Count of Default & Not Default": Total_list, "Sum of Default": Default_list,"Sum of Not Default":Not_Default_list})
df = df.set_index(Numbers)
df = df.drop_duplicates('Sum of Default')

# %%
percent_default =(df["Sum of Default"]/df["Total Count of Default & Not Default"]*100).tolist()
percent_not_default = (df["Sum of Not Default"]/df["Total Count of Default & Not Default"]*100).tolist()


ind = np.arange(len(percent_default))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(ind - width/2, percent_default, width,label= "Default")
rects2 = ax.bar(ind + width/2, percent_not_default, width, label= "Paid")

ax.set_ylabel('Percentage')
ax.set_title('Percentage vs Home Value')
ax.set_xticks(ind)
ax.set_xticklabels(('$10k','$25k','$50k','$75k','$100k','$125k','$150k'))
ax.legend()
